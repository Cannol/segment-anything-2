# %% [markdown]
# # Feature Testing with SAM2
# 1. inference all frames
# 2. obtain multi-layer deep features from SAM2-Encoder, save them in one folder with numpy format
# 3. get pooling result from these features (squeeze channels to 1)
# 4. PAC(Principal Component Analysis) to feature vector
# 5. using DBSCAN to clustering these frames
# 6. plot them out
